# %% [markdown]
# # * LOADING DATASET
# # * CREATING SEPARATE DATASETS FOR CATEGORICAL AND NUMERICAL COLUMNS
# # * CREATING FUNCTIONS FOR DESCRIBING CATEGORICAL AND NUMERICAL DATASETS
# # * CHECKING FOR MISSING VALUES AND FILLING THE MISSING VALUES
# # * VISUALIZING THE CATEGORICAL , NUMERICAL DATASETS
# # * CREATING A FUNCTION FOR ANALYSING AND VISUALISING THE CATEGORICAL , NUMERICAL DATASETS
#
# > Add blockquote

# %% [markdown]
# #  LOADING DATASET

# %%
# LOADING THE DATASET INDIAN TRAFFIC VIOLATIONS
import numpy as np
import pandas as pd

df=pd.read_csv("Indian_Traffic_Violations.csv")
df.head()
# Out:
#   Violation_ID           Violation_Type  Fine_Amount       Location  \
# 0    VLT100000              Overloading         4544      Karnataka
# 1    VLT100001  Driving Without License         2776         Punjab
# 2    VLT100002       Using Mobile Phone         4785    Maharashtra
# 3    VLT100003              No Seatbelt         1138  Uttar Pradesh
# 4    VLT100004            Over-speeding         1610      Karnataka
#
#          Date   Time Vehicle_Type Vehicle_Color  Vehicle_Model_Year  \
# 0  2023-01-01  23:02          Car           Red                2012
# 1  2023-01-02  00:42      Scooter        Silver                2010
# 2  2023-01-03  04:32      Scooter          Grey                2006
# 3  2023-01-04  15:06          Car         Green                1996
# 4  2023-01-05  06:57        Truck        Yellow                2016
#
#   Registration_State  ...  Speed_Limit Recorded_Speed Alcohol_Level  \
# 0        West Bengal  ...          100             95          0.03
# 1         Tamil Nadu  ...           40             48          0.45
# 2         Tamil Nadu  ...           80             26          0.31
# 3      Uttar Pradesh  ...          100            115          0.09
# 4              Delhi  ...           30            115          0.28
#
#    Breathalyzer_Result Towed Fine_Paid Payment_Method  \
# 0             Negative   Yes        No         Online
# 1             Negative   Yes       Yes         Online
# 2        Not Conducted    No        No       Not Paid
# 3        Not Conducted    No       Yes         Online
# 4             Positive    No       Yes           Cash
#
#   Court_Appearance_Required Previous_Violations         Comments
# 0                       Yes                   3  Repeat Offender
# 1                        No                   2  Repeat Offender
# 2                       Yes                   4              NaN
# 3                        No                   5  Repeat Offender
# 4                       Yes                   0              NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # DATA ANALYSIS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Violation_ID               4000 non-null   object
#  1   Violation_Type             4000 non-null   object
#  2   Fine_Amount                4000 non-null   int64
#  3   Location                   4000 non-null   object
#  4   Date                       4000 non-null   object
#  5   Time                       4000 non-null   object
#  6   Vehicle_Type               4000 non-null   object
#  7   Vehicle_Color              4000 non-null   object
#  8   Vehicle_Model_Year         4000 non-null   int64
#  9   Registration_State         4000 non-null   object
#  10  Driver_Age                 4000 non-null   int64
#  11  Driver_Gender              4000 non-null   object
#  12  License_Type               4000 non-null   object
#  13  Penalty_Points             4000 non-null   int64
#  14  Weather_Condition          4000 non-null   object
#  15  Road_Condition             4000 non-null   object
#  16  Officer_ID                 4000 non-null   object
#  17  Issuing_Agency             4000 non-null   object
#  18  License_Validity           4000 non-null   object
#  19  Number_of_Passengers       4000 non-null   int64
#  20  Helmet_Worn                2651 non-null   object
#  21  Seatbelt_Worn              2708 non-null   object
#  22  Traffic_Light_Status       4000 non-null   object
#  23  Speed_Limit                4000 non-null   int64
#  24  Recorded_Speed             4000 non-null   int64
#  25  Alcohol_Level              4000 non-null   float64
#  26  Breathalyzer_Result        4000 non-null   object
#  27  Towed                      4000 non-null   object
#  28  Fine_Paid                  4000 non-null   object
#  29  Payment_Method             4000 non-null   object
#  30  Court_Appearance_Required  4000 non-null   object
#  31  Previous_Violations        4000 non-null   int64
#  32  Comments                   3004 non-null   object
# dtypes: float64(1), int64(8), object(24)
# memory usage: 1.0+ MB

# %% [markdown]
# # CREATING SEPARATE DATASETS FOR CATEGORICAL AND NUMERICAL COLUMNS

# %%
# CREATING A DATASET FOR NUMERICAL COLUMNS
num_df=df.select_dtypes(include=["int","float"])
num_df.head()
# Out:
#    Fine_Amount  Vehicle_Model_Year  Driver_Age  Penalty_Points  \
# 0         4544                2012          25               5
# 1         2776                2010          32               4
# 2         4785                2006          67               8
# 3         1138                1996          46               3
# 4         1610                2016          63               4
#
#    Number_of_Passengers  Speed_Limit  Recorded_Speed  Alcohol_Level  \
# 0                     4          100              95           0.03
# 1                     4           40              48           0.45
# 2                     5           80              26           0.31
# 3                     2          100             115           0.09
# 4                     4           30             115           0.28
#
#    Previous_Violations
# 0                    3
# 1                    2
# 2                    4
# 3                    5
# 4                    0

# %%
# CREATING A DATASET FOR CATEGORICAL COLUMNS
cat_df=df.select_dtypes(include="object")
cat_df.head()
# Out:
#   Violation_ID           Violation_Type       Location        Date   Time  \
# 0    VLT100000              Overloading      Karnataka  2023-01-01  23:02
# 1    VLT100001  Driving Without License         Punjab  2023-01-02  00:42
# 2    VLT100002       Using Mobile Phone    Maharashtra  2023-01-03  04:32
# 3    VLT100003              No Seatbelt  Uttar Pradesh  2023-01-04  15:06
# 4    VLT100004            Over-speeding      Karnataka  2023-01-05  06:57
#
#   Vehicle_Type Vehicle_Color Registration_State Driver_Gender  License_Type  \
# 0          Car           Red        West Bengal          Male    Commercial
# 1      Scooter        Silver         Tamil Nadu        Female    Commercial
# 2      Scooter          Grey         Tamil Nadu        Female   Two-Wheeler
# 3          Car         Green      Uttar Pradesh          Male       Learner
# 4        Truck        Yellow              Delhi        Female  Four-Wheeler
#
#    ... License_Validity Helmet_Worn Seatbelt_Worn Traffic_Light_Status  \
# 0  ...            Valid         NaN           Yes                Green
# 1  ...            Valid         NaN            No                Green
# 2  ...            Valid         Yes           Yes               Yellow
# 3  ...            Valid          No            No                Green
# 4  ...            Valid         NaN            No                  Red
#
#   Breathalyzer_Result Towed Fine_Paid Payment_Method  \
# 0            Negative   Yes        No         Online
# 1            Negative   Yes       Yes         Online
# 2       Not Conducted    No        No       Not Paid
# 3       Not Conducted    No       Yes         Online
# 4            Positive    No       Yes           Cash
#
#   Court_Appearance_Required         Comments
# 0                       Yes  Repeat Offender
# 1                        No  Repeat Offender
# 2                       Yes              NaN
# 3                        No  Repeat Offender
# 4                       Yes              NaN
#
# [5 rows x 24 columns]

# %%
# CATEGORICAL DESCRIPTION OF THE CATEGORICAL COLUMNS IN THE DATASET
for i in cat_df.columns:
 print("categorical description of column ",i)
 print("\n")
 def cat_desc(column):
  print("unique values of column = ",cat_df[column].unique())
  print("number of unique values =",cat_df[column].nunique())
  print("count of column = ",cat_df[column].count())
  print("mode of column = ",cat_df[column].mode())
  print("\n")
  print("\n")
 cat_desc(i)
# Out:
# categorical description of column  Violation_ID
#
#
# unique values of column =  ['VLT100000' 'VLT100001' 'VLT100002' ... 'VLT103997' 'VLT103998'
#  'VLT103999']
# number of unique values = 4000
# count of column =  4000
# mode of column =  0       VLT100000
# 1       VLT100001
# 2       VLT100002
# 3       VLT100003
# 4       VLT100004
#           ...
# 3995    VLT103995
# 3996    VLT103996
# 3997    VLT103997
# 3998    VLT103998
# 3999    VLT103999
# Name: Violation_ID, Length: 4000, dtype: object
#
#
#
#
# categorical description of column  Violation_Type
#
#
# unique values of column =  ['Overloading' 'Driving Without License' 'Using Mobile Phone'
#  'No Seatbelt' 'Over-speeding' 'Wrong Parking' 'No Helmet'
#  'Signal Jumping' 'Drunk Driving']
# number of unique values = 9
# count of column =  4000
# mode of column =  0    Drunk Driving
# Name: Violation_Type, dtype: object
#
#
#
#
# categorical description of column  Location
#
#
# unique values of column =  ['Karnataka' 'Punjab' 'Maharashtra' 'Uttar Pradesh' 'West Bengal' 'Delhi'
#  'Tamil Nadu' 'Gujarat']
# number of unique values = 8
# count of column =  4000
# mode of column =  0    Gujarat
# Name: Location, dtype: object
#
#
#
#
# categorical description of column  Date
#
#
# unique values of column =  ['2023-01-01' '2023-01-02' '2023-01-03' ... '2033-12-11' '2033-12-12'
#  '2033-12-13']
# number of unique values = 4000
# count of column =  4000
# mode of column =  0       2023-01-01
# 1       2023-01-02
# 2       2023-01-03
# 3       2023-01-04
# 4       2023-01-05
#            ...
# 3995    2033-12-09
# 3996    2033-12-10
# 3997    2033-12-11
# 3998    2033-12-12
# 3999    2033-12-13
# Name: Date, Length: 4000, dtype: object
#
#
#
#
# categorical description of column  Time
#
#
# unique values of column =  ['23:02' '00:42' '04:32' ... '13:06' '14:49' '07:47']
# number of unique values = 1359
# count of column =  4000
# mode of column =  0     03:56
# 1     04:27
# 2     06:32
# 3     08:05
# 4     13:52
# 5     14:41
# 6     15:05
# 7     16:30
# 8     17:01
# 9     17:12
# 10    21:56
# Name: Time, dtype: object
#
#
#
#
# categorical description of column  Vehicle_Type
#
#
# unique values of column =  ['Car' 'Scooter' 'Truck' 'Bus' 'Auto Rickshaw' 'Bike']
# number of unique values = 6
# count of column =  4000
# mode of column =  0    Scooter
# Name: Vehicle_Type, dtype: object
#
#
#
#
# categorical description of column  Vehicle_Color
#
#
# unique values of column =  ['Red' 'Silver' 'Grey' 'Green' 'Yellow' 'White' 'Black' 'Blue']
# number of unique values = 8
# count of column =  4000
# mode of column =  0    Grey
# Name: Vehicle_Color, dtype: object
#
#
#
#
# categorical description of column  Registration_State
#
#
# unique values of column =  ['West Bengal' 'Tamil Nadu' 'Uttar Pradesh' 'Delhi' 'Gujarat' 'Punjab'
#  'Maharashtra' 'Karnataka']
# number of unique values = 8
# count of column =  4000
# mode of column =  0    Maharashtra
# Name: Registration_State, dtype: object
#
#
#
#
# categorical description of column  Driver_Gender
#
#
# unique values of column =  ['Male' 'Female' 'Other']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Male
# Name: Driver_Gender, dtype: object
#
#
#
#
# categorical description of column  License_Type
#
#
# unique values of column =  ['Commercial' 'Two-Wheeler' 'Learner' 'Four-Wheeler' 'Heavy Vehicle']
# number of unique values = 5
# count of column =  4000
# mode of column =  0    Heavy Vehicle
# Name: License_Type, dtype: object
#
#
#
#
# categorical description of column  Weather_Condition
#
#
# unique values of column =  ['Cloudy' 'Rainy' 'Clear' 'Foggy' 'Dust Storm']
# number of unique values = 5
# count of column =  4000
# mode of column =  0    Rainy
# Name: Weather_Condition, dtype: object
#
#
#
#
# categorical description of column  Road_Condition
#
#
# unique values of column =  ['Slippery' 'Dry' 'Potholes' 'Wet' 'Under Construction']
# number of unique values = 5
# count of column =  4000
# mode of column =  0    Slippery
# Name: Road_Condition, dtype: object
#
#
#
#
# categorical description of column  Officer_ID
#
#
# unique values of column =  ['OFF9971' 'OFF6000' 'OFF5706' ... 'OFF6779' 'OFF9910' 'OFF1887']
# number of unique values = 3215
# count of column =  4000
# mode of column =  0    OFF5164
# Name: Officer_ID, dtype: object
#
#
#
#
# categorical description of column  Issuing_Agency
#
#
# unique values of column =  ['Local Police' 'Highway Patrol' 'Traffic Police' 'RTO']
# number of unique values = 4
# count of column =  4000
# mode of column =  0    Traffic Police
# Name: Issuing_Agency, dtype: object
#
#
#
#
# categorical description of column  License_Validity
#
#
# unique values of column =  ['Valid' 'Expired' 'Suspended']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Suspended
# Name: License_Validity, dtype: object
#
#
#
#
# categorical description of column  Helmet_Worn
#
#
# unique values of column =  [nan 'Yes' 'No']
# number of unique values = 2
# count of column =  2651
# mode of column =  0    Yes
# Name: Helmet_Worn, dtype: object
#
#
#
#
# categorical description of column  Seatbelt_Worn
#
#
# unique values of column =  ['Yes' 'No' nan]
# number of unique values = 2
# count of column =  2708
# mode of column =  0    No
# Name: Seatbelt_Worn, dtype: object
#
#
#
#
# categorical description of column  Traffic_Light_Status
#
#
# unique values of column =  ['Green' 'Yellow' 'Red']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Green
# Name: Traffic_Light_Status, dtype: object
#
#
#
#
# categorical description of column  Breathalyzer_Result
#
#
# unique values of column =  ['Negative' 'Not Conducted' 'Positive']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Not Conducted
# Name: Breathalyzer_Result, dtype: object
#
#
#
#
# categorical description of column  Towed
#
#
# unique values of column =  ['Yes' 'No']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    No
# Name: Towed, dtype: object
#
#
#
#
# categorical description of column  Fine_Paid
#
#
# unique values of column =  ['No' 'Yes']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    No
# Name: Fine_Paid, dtype: object
#
#
#
#
# categorical description of column  Payment_Method
#
#
# unique values of column =  ['Online' 'Not Paid' 'Cash' 'Card']
# number of unique values = 4
# count of column =  4000
# mode of column =  0    Cash
# Name: Payment_Method, dtype: object
#
#
#
#
# categorical description of column  Court_Appearance_Required
#
#
# unique values of column =  ['Yes' 'No']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    Yes
# Name: Court_Appearance_Required, dtype: object
#
#
#
#
# categorical description of column  Comments
#
#
# unique values of column =  ['Repeat Offender' nan 'Fine Paid On Spot' 'First Violation']
# number of unique values = 3
# count of column =  3004
# mode of column =  0    Fine Paid On Spot
# Name: Comments, dtype: object

# %%
# NUMERICAL DESCRIPTION FOR NUMERICAL COLUMNS IN DATASET

for i in num_df.columns:
  print("numerical description of column ",i)
  print("\n")
  def num_desc(column):
    print("Average value of the column =",num_df[column].mean())
    print("Median value of the column =",num_df[column].median())
    print("Maximum value of the column =",num_df[column].max())
    print("Minimum value of the column =",num_df[column].min())
    print("Sum of all values in the column =",num_df[column].sum())
    print("Variance of the column =",num_df[column].var())
    print("Standard deviation of the column =",num_df[column].std())
    print("\n")
    print("\n")
  num_desc(i)
# Out:
# numerical description of column  Fine_Amount
#
#
# Average value of the column = 2529.82125
# Median value of the column = 2506.0
# Maximum value of the column = 5000
# Minimum value of the column = 100
# Sum of all values in the column = 10119285
# Variance of the column = 2009067.3006235936
# Standard deviation of the column = 1417.415711999692
#
#
#
#
# numerical description of column  Vehicle_Model_Year
#
#
# Average value of the column = 2008.9105
# Median value of the column = 2009.0
# Maximum value of the column = 2023
# Minimum value of the column = 1995
# Sum of all values in the column = 8035642
# Variance of the column = 69.44235033758603
# Standard deviation of the column = 8.333207685974592
#
#
#
#
# numerical description of column  Driver_Age
#
#
# Average value of the column = 46.658
# Median value of the column = 47.0
# Maximum value of the column = 75
# Minimum value of the column = 18
# Sum of all values in the column = 186632
# Variance of the column = 284.45715028757246
# Standard deviation of the column = 16.8658575319363
#
#
#
#
# numerical description of column  Penalty_Points
#
#
# Average value of the column = 4.9605
# Median value of the column = 5.0
# Maximum value of the column = 10
# Minimum value of the column = 0
# Sum of all values in the column = 19842
# Variance of the column = 9.969432108026973
# Standard deviation of the column = 3.1574407528925974
#
#
#
#
# numerical description of column  Number_of_Passengers
#
#
# Average value of the column = 3.0005
# Median value of the column = 3.0
# Maximum value of the column = 5
# Minimum value of the column = 1
# Sum of all values in the column = 12002
# Variance of the column = 1.990497374343544
# Standard deviation of the column = 1.4108498766146396
#
#
#
#
# numerical description of column  Speed_Limit
#
#
# Average value of the column = 59.8175
# Median value of the column = 60.0
# Maximum value of the column = 100
# Minimum value of the column = 30
# Sum of all values in the column = 239270
# Variance of the column = 558.5313265816474
# Standard deviation of the column = 23.633267369994513
#
#
#
#
# numerical description of column  Recorded_Speed
#
#
# Average value of the column = 69.479
# Median value of the column = 70.0
# Maximum value of the column = 120
# Minimum value of the column = 20
# Sum of all values in the column = 277916
# Variance of the column = 864.0455703925999
# Standard deviation of the column = 29.394652071296914
#
#
#
#
# numerical description of column  Alcohol_Level
#
#
# Average value of the column = 0.2514075
# Median value of the column = 0.25
# Maximum value of the column = 0.5
# Minimum value of the column = 0.0
# Sum of all values in the column = 1005.6300000000001
# Variance of the column = 0.020662259508627167
# Standard deviation of the column = 0.14374372858885764
#
#
#
#
# numerical description of column  Previous_Violations
#
#
# Average value of the column = 2.4775
# Median value of the column = 2.0
# Maximum value of the column = 5
# Minimum value of the column = 0
# Sum of all values in the column = 9910
# Variance of the column = 2.9377281820453875
# Standard deviation of the column = 1.7139802163518072

# %% [markdown]
# # CHECKING FOR THE MISSING VALUES

# %%
num_df.isnull().sum()
# Out:
# Fine_Amount             0
# Vehicle_Model_Year      0
# Driver_Age              0
# Penalty_Points          0
# Number_of_Passengers    0
# Speed_Limit             0
# Recorded_Speed          0
# Alcohol_Level           0
# Previous_Violations     0
# dtype: int64

# %%
cat_df.isnull().sum()
# Out:
# Violation_ID                    0
# Violation_Type                  0
# Location                        0
# Date                            0
# Time                            0
# Vehicle_Type                    0
# Vehicle_Color                   0
# Registration_State              0
# Driver_Gender                   0
# License_Type                    0
# Weather_Condition               0
# Road_Condition                  0
# Officer_ID                      0
# Issuing_Agency                  0
# License_Validity                0
# Helmet_Worn                  1349
# Seatbelt_Worn                1292
# Traffic_Light_Status            0
# Breathalyzer_Result             0
# Towed                           0
# Fine_Paid                       0
# Payment_Method                  0
# Court_Appearance_Required       0
# Comments                      996
# dtype: int64

# %% [markdown]
# # FILLING THE MISSING VALUES IN THE CAT_DF WITH MODE

# %%
cat_df["Helmet_Worn"]=cat_df["Helmet_Worn"].fillna(cat_df["Helmet_Worn"].mode()[0])
cat_df["Seatbelt_Worn"]=cat_df["Seatbelt_Worn"].fillna(cat_df['Seatbelt_Worn'].mode()[0])
cat_df.isnull().sum()
# Out:
# Violation_ID                   0
# Violation_Type                 0
# Location                       0
# Date                           0
# Time                           0
# Vehicle_Type                   0
# Vehicle_Color                  0
# Registration_State             0
# Driver_Gender                  0
# License_Type                   0
# Weather_Condition              0
# Road_Condition                 0
# Officer_ID                     0
# Issuing_Agency                 0
# License_Validity               0
# Helmet_Worn                    0
# Seatbelt_Worn                  0
# Traffic_Light_Status           0
# Breathalyzer_Result            0
# Towed                          0
# Fine_Paid                      0
# Payment_Method                 0
# Court_Appearance_Required      0
# Comments                     996
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def num_visualize(col_name):
   plt.boxplot(num_df[col_name])
   plt.show()
for i in num_df.columns:
  print("visualizing the col ",i )
  num_visualize(i)
# Out:
# visualizing the col  Fine_Amount
# visualizing the col  Vehicle_Model_Year
# visualizing the col  Driver_Age
# visualizing the col  Penalty_Points
# visualizing the col  Number_of_Passengers
# visualizing the col  Speed_Limit
# visualizing the col  Recorded_Speed
# visualizing the col  Alcohol_Level
# visualizing the col  Previous_Violations

# %%
def cat_visualize(col_name):
     sns.countplot(cat_df,x=i)
     plt.show()
for i in cat_df.columns:
    print("visualizing the col ",i )
    cat_visualize(i)
# Out:
# visualizing the col  Violation_ID
# visualizing the col  Violation_Type
# visualizing the col  Location
# visualizing the col  Date
# visualizing the col  Time
# visualizing the col  Vehicle_Type
# visualizing the col  Vehicle_Color
# visualizing the col  Registration_State
# visualizing the col  Driver_Gender
# visualizing the col  License_Type
# visualizing the col  Weather_Condition
# visualizing the col  Road_Condition
# visualizing the col  Officer_ID
# visualizing the col  Issuing_Agency
# visualizing the col  License_Validity
# visualizing the col  Helmet_Worn
# visualizing the col  Seatbelt_Worn
# visualizing the col  Traffic_Light_Status
# visualizing the col  Breathalyzer_Result
# visualizing the col  Towed
# visualizing the col  Fine_Paid
# visualizing the col  Payment_Method
# visualizing the col  Court_Appearance_Required
# visualizing the col  Comments

# %% [markdown]
# # CREATING A FUNCTION FOR BOTH ANALYSING AND VISUALIZING A DATASET

# %%
def analyse_visualise(df):
 for i in df.columns:
  if i in cat_df:
    cat_desc(i)
    cat_visualize(i)
  else:
    num_desc(i)
    num_visualize(i)

# %%
analyse_visualise(df)
# Out:
# unique values of column =  ['VLT100000' 'VLT100001' 'VLT100002' ... 'VLT103997' 'VLT103998'
#  'VLT103999']
# number of unique values = 4000
# count of column =  4000
# mode of column =  0       VLT100000
# 1       VLT100001
# 2       VLT100002
# 3       VLT100003
# 4       VLT100004
#           ...
# 3995    VLT103995
# 3996    VLT103996
# 3997    VLT103997
# 3998    VLT103998
# 3999    VLT103999
# Name: Violation_ID, Length: 4000, dtype: object
# unique values of column =  ['Overloading' 'Driving Without License' 'Using Mobile Phone'
#  'No Seatbelt' 'Over-speeding' 'Wrong Parking' 'No Helmet'
#  'Signal Jumping' 'Drunk Driving']
# number of unique values = 9
# count of column =  4000
# mode of column =  0    Drunk Driving
# Name: Violation_Type, dtype: object
# Average value of the column = 2529.82125
# Median value of the column = 2506.0
# Maximum value of the column = 5000
# Minimum value of the column = 100
# Sum of all values in the column = 10119285
# Variance of the column = 2009067.3006235936
# Standard deviation of the column = 1417.415711999692
# unique values of column =  ['Karnataka' 'Punjab' 'Maharashtra' 'Uttar Pradesh' 'West Bengal' 'Delhi'
#  'Tamil Nadu' 'Gujarat']
# number of unique values = 8
# count of column =  4000
# mode of column =  0    Gujarat
# Name: Location, dtype: object
# unique values of column =  ['2023-01-01' '2023-01-02' '2023-01-03' ... '2033-12-11' '2033-12-12'
#  '2033-12-13']
# number of unique values = 4000
# count of column =  4000
# mode of column =  0       2023-01-01
# 1       2023-01-02
# 2       2023-01-03
# 3       2023-01-04
# 4       2023-01-05
#            ...
# 3995    2033-12-09
# 3996    2033-12-10
# 3997    2033-12-11
# 3998    2033-12-12
# 3999    2033-12-13
# Name: Date, Length: 4000, dtype: object
# unique values of column =  ['23:02' '00:42' '04:32' ... '13:06' '14:49' '07:47']
# number of unique values = 1359
# count of column =  4000
# mode of column =  0     03:56
# 1     04:27
# 2     06:32
# 3     08:05
# 4     13:52
# 5     14:41
# 6     15:05
# 7     16:30
# 8     17:01
# 9     17:12
# 10    21:56
# Name: Time, dtype: object
# unique values of column =  ['Car' 'Scooter' 'Truck' 'Bus' 'Auto Rickshaw' 'Bike']
# number of unique values = 6
# count of column =  4000
# mode of column =  0    Scooter
# Name: Vehicle_Type, dtype: object
# unique values of column =  ['Red' 'Silver' 'Grey' 'Green' 'Yellow' 'White' 'Black' 'Blue']
# number of unique values = 8
# count of column =  4000
# mode of column =  0    Grey
# Name: Vehicle_Color, dtype: object
# Average value of the column = 2008.9105
# Median value of the column = 2009.0
# Maximum value of the column = 2023
# Minimum value of the column = 1995
# Sum of all values in the column = 8035642
# Variance of the column = 69.44235033758603
# Standard deviation of the column = 8.333207685974592
# unique values of column =  ['West Bengal' 'Tamil Nadu' 'Uttar Pradesh' 'Delhi' 'Gujarat' 'Punjab'
#  'Maharashtra' 'Karnataka']
# number of unique values = 8
# count of column =  4000
# mode of column =  0    Maharashtra
# Name: Registration_State, dtype: object
# Average value of the column = 46.658
# Median value of the column = 47.0
# Maximum value of the column = 75
# Minimum value of the column = 18
# Sum of all values in the column = 186632
# Variance of the column = 284.45715028757246
# Standard deviation of the column = 16.8658575319363
# unique values of column =  ['Male' 'Female' 'Other']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Male
# Name: Driver_Gender, dtype: object
# unique values of column =  ['Commercial' 'Two-Wheeler' 'Learner' 'Four-Wheeler' 'Heavy Vehicle']
# number of unique values = 5
# count of column =  4000
# mode of column =  0    Heavy Vehicle
# Name: License_Type, dtype: object
# Average value of the column = 4.9605
# Median value of the column = 5.0
# Maximum value of the column = 10
# Minimum value of the column = 0
# Sum of all values in the column = 19842
# Variance of the column = 9.969432108026973
# Standard deviation of the column = 3.1574407528925974
# unique values of column =  ['Cloudy' 'Rainy' 'Clear' 'Foggy' 'Dust Storm']
# number of unique values = 5
# count of column =  4000
# mode of column =  0    Rainy
# Name: Weather_Condition, dtype: object
# unique values of column =  ['Slippery' 'Dry' 'Potholes' 'Wet' 'Under Construction']
# number of unique values = 5
# count of column =  4000
# mode of column =  0    Slippery
# Name: Road_Condition, dtype: object
# unique values of column =  ['OFF9971' 'OFF6000' 'OFF5706' ... 'OFF6779' 'OFF9910' 'OFF1887']
# number of unique values = 3215
# count of column =  4000
# mode of column =  0    OFF5164
# Name: Officer_ID, dtype: object
# unique values of column =  ['Local Police' 'Highway Patrol' 'Traffic Police' 'RTO']
# number of unique values = 4
# count of column =  4000
# mode of column =  0    Traffic Police
# Name: Issuing_Agency, dtype: object
# unique values of column =  ['Valid' 'Expired' 'Suspended']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Suspended
# Name: License_Validity, dtype: object
# Average value of the column = 3.0005
# Median value of the column = 3.0
# Maximum value of the column = 5
# Minimum value of the column = 1
# Sum of all values in the column = 12002
# Variance of the column = 1.990497374343544
# Standard deviation of the column = 1.4108498766146396
# unique values of column =  ['Yes' 'No']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    Yes
# Name: Helmet_Worn, dtype: object
# unique values of column =  ['Yes' 'No']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    No
# Name: Seatbelt_Worn, dtype: object
# unique values of column =  ['Green' 'Yellow' 'Red']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Green
# Name: Traffic_Light_Status, dtype: object
# Average value of the column = 59.8175
# Median value of the column = 60.0
# Maximum value of the column = 100
# Minimum value of the column = 30
# Sum of all values in the column = 239270
# Variance of the column = 558.5313265816474
# Standard deviation of the column = 23.633267369994513
# Average value of the column = 69.479
# Median value of the column = 70.0
# Maximum value of the column = 120
# Minimum value of the column = 20
# Sum of all values in the column = 277916
# Variance of the column = 864.0455703925999
# Standard deviation of the column = 29.394652071296914
# Average value of the column = 0.2514075
# Median value of the column = 0.25
# Maximum value of the column = 0.5
# Minimum value of the column = 0.0
# Sum of all values in the column = 1005.6300000000001
# Variance of the column = 0.020662259508627167
# Standard deviation of the column = 0.14374372858885764
# unique values of column =  ['Negative' 'Not Conducted' 'Positive']
# number of unique values = 3
# count of column =  4000
# mode of column =  0    Not Conducted
# Name: Breathalyzer_Result, dtype: object
# unique values of column =  ['Yes' 'No']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    No
# Name: Towed, dtype: object
# unique values of column =  ['No' 'Yes']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    No
# Name: Fine_Paid, dtype: object
# unique values of column =  ['Online' 'Not Paid' 'Cash' 'Card']
# number of unique values = 4
# count of column =  4000
# mode of column =  0    Cash
# Name: Payment_Method, dtype: object
# unique values of column =  ['Yes' 'No']
# number of unique values = 2
# count of column =  4000
# mode of column =  0    Yes
# Name: Court_Appearance_Required, dtype: object
# Average value of the column = 2.4775
# Median value of the column = 2.0
# Maximum value of the column = 5
# Minimum value of the column = 0
# Sum of all values in the column = 9910
# Variance of the column = 2.9377281820453875
# Standard deviation of the column = 1.7139802163518072
# unique values of column =  ['Repeat Offender' nan 'Fine Paid On Spot' 'First Violation']
# number of unique values = 3
# count of column =  3004
# mode of column =  0    Fine Paid On Spot
# Name: Comments, dtype: object
